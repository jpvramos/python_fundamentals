# %% [markdown]
# # Time Series

# %%
import pandas as pd
import numpy as np
# Criando um range de datas com frequencia de segundo 

rng= pd.date_range('1/1/2018', periods = 50, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index = rng)

# %%
ts
# Out:
# 2018-01-01 00:00:00     43
# 2018-01-01 00:00:01    255
# 2018-01-01 00:00:02    208
# 2018-01-01 00:00:03    485
# 2018-01-01 00:00:04    178
# 2018-01-01 00:00:05     76
# 2018-01-01 00:00:06    298
# 2018-01-01 00:00:07    392
# 2018-01-01 00:00:08     22
# 2018-01-01 00:00:09    143
# 2018-01-01 00:00:10    449
# 2018-01-01 00:00:11    354
# 2018-01-01 00:00:12     65
# 2018-01-01 00:00:13    379
# 2018-01-01 00:00:14    187
# 2018-01-01 00:00:15    242
# 2018-01-01 00:00:16    152
# 2018-01-01 00:00:17    485
# 2018-01-01 00:00:18    131
# 2018-01-01 00:00:19    434
# 2018-01-01 00:00:20    188
# 2018-01-01 00:00:21     45
# 2018-01-01 00:00:22    300
# 2018-01-01 00:00:23    430
# 2018-01-01 00:00:24    378
# 2018-01-01 00:00:25    466
# 2018-01-01 00:00:26    270
# 2018-01-01 00:00:27    401
# 2018-01-01 00:00:28    351
# 2018-01-01 00:00:29    194
# 2018-01-01 00:00:30      7
# 2018-01-01 00:00:31    112
# 2018-01-01 00:00:32    171
# 2018-01-01 00:00:33    264
# 2018-01-01 00:00:34    234
# 2018-01-01 00:00:35     10
# 2018-01-01 00:00:36    190
# 2018-01-01 00:00:37    122
# 2018-01-01 00:00:38    280
# 2018-01-01 00:00:39    405
# 2018-01-01 00:00:40    315
# 2018-01-01 00:00:41    399
# 2018-01-01 00:00:42    417
# 2018-01-01 00:00:43     39
# 2018-01-01 00:00:44    325
# 2018-01-01 00:00:45    436
# 2018-01-01 00:00:46     94
# 2018-01-01 00:00:47    113
# 2018-01-01 00:00:48    155
# 2018-01-01 00:00:49    252
# Freq: S, dtype: int32

# %%
# Criando um range de datas com frequência de meses 
rng = pd.date_range('1/1/2016', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2016-01-31    0.871746
# 2016-02-29   -0.260386
# 2016-03-31   -0.547798
# 2016-04-30   -1.354595
# 2016-05-31   -1.608001
# Freq: M, dtype: float64

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
# Time Series Plot 
ts = pd.Series(np.random.randn(500), index=pd.date_range('1/1/2016', periods=500))
ts[0] = 100
ts = ts.cumsum()
ts.plot()
